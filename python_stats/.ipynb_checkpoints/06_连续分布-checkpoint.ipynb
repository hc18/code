# %% [markdown]
# # Continuous Distribution Functions
# - t-Distribution: The sample distribution of mean values for samples from a normally distributed population. Typically used for small sample numbers, when the true mean/SD are not known.
# - X-Square distribution: For describing variability of normally distributed data.
# - F-distribution: For comparing variabilities of two sets of normally distributed data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy import stats
n = 20
df = n-1
alpha = 0.05
stats.t(df).isf(alpha/2)
# Out:
# 2.0930240544082634

# %%
stats.norm.isf(alpha/2)
# Out:
# 1.9599639845400545

# %%
alpha = 0.95
df = len(data)-1
ci = stats.t.interval(alpha, df,loc=np.mean(data), scale=stats.sem(data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e0c960c6e389> in <module>
#       1 alpha = 0.95
# ----> 2 df = len(data)-1
#       3 ci = stats.t.interval(alpha, df,loc=np.mean(data), scale=stats.sem(data))
#
# NameError: name 'data' is not defined

# %% [markdown]
# # Chi-Square Distribution
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy import stats
data = np.r_[3.04, 2.94, 3.01, 3.00, 2.94, 2.91, 3.02,3.04, 3.09, 2.95, 2.99, 3.10, 3.02]
sigma = 0.05
chi2Dist = stats.chi2(len(data)-1)
statistic = sum( ((data-np.mean(data))/sigma)**2 )
chi2Dist.sf(statistic)
# Out:
# 0.19293306654285156

# %% [markdown]
# # F-Distribution
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy import stats
method1 = np.array([20.7, 20.3, 20.3, 20.3, 20.7, 19.9, 19.9, 19.9, 20.3, 20.3, 19.7, 20.3])
method2 = np.array([ 19.7, 19.4, 20.1, 18.6, 18.8, 20.2, 18.7, 19. ])
fval = np.var(method1, ddof=1)/np.var(method2, ddof=1) 
fd = stats.f(len(method1)-1,len(method2)-1)
p_oneTail = fd.cdf(fval) # -> 0.019
if (p_oneTail<0.025) or (p_oneTail>0.975): 
    print('There is a significant difference between the two distributions.') 
else:
    print('No significant difference.')
# Out:
# There is a significant difference between the two distributions.
